# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.model_selection import KFold, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("LondonCars2014.csv")

# %% [markdown]
# ### Performing EDA on the dataset

# %%
df.head()
# Out:
#       Make                           Model  Year  Mileage  Price Body Style  \
# 0   Toyota                      Avalon XLE  2014     4725  28995      Sedan
# 1     Ford                       Escape SE  2014    17201  24994        SUV
# 2  Hyundai                  Santa Fe Sport  2014     6279  25998        SUV
# 3     Ford                       Escape SE  2014    16262  26684        SUV
# 4     Jeep  Grand Cherokee Limited Edition  2014    35572  33440        SUV
#
#   Ex Color In Color Engine Transmission  Doors
# 0     Gray    Black  6 Cyl    Automatic      4
# 1   Silver    Black  4 Cyl    Automatic      4
# 2   Silver     Gray  4 Cyl    Automatic      4
# 3    Black    Black  4 Cyl    Automatic      4
# 4    Black    Black  6 Cyl    Automatic      4

# %%
df.tail()
# Out:
#                Make        Model  Year  Mileage  Price Body Style Ex Color  \
# 9075      Chevrolet    Malibu LT  2010    40340  12998      Sedan   Silver
# 9076           Ford     Edge SEL  2009    43169  18495        SUV     Blue
# 9077          Dodge  Avenger SXT  2012     6761  14944      Sedan   Silver
# 9078  Mercedes-Benz       ML 350  2011    38215  35900        SUV   Silver
# 9079         Nissan    Altima SL  2010    44065  13499      Sedan     Gray
#
#      In Color Engine Transmission  Doors
# 9075    Black  4 Cyl    Automatic      4
# 9076     Gray  6 Cyl    Automatic      4
# 9077    Black  4 Cyl    Automatic      4
# 9078    Black  6 Cyl    Automatic      4
# 9079    Black  4 Cyl    Automatic      4

# %%
print("Nulls:\n", df.isnull().sum())
# Out:
# Nulls:
#  Make            0
# Model           0
# Year            0
# Mileage         0
# Price           0
# Body Style      0
# Ex Color        0
# In Color        0
# Engine          0
# Transmission    0
# Doors           0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#           Make     Model         Year        Mileage          Price  \
# count     9080      9080  9080.000000    9080.000000    9080.000000
# unique      49      1060          NaN            NaN            NaN
# top     Nissan  Altima S          NaN            NaN            NaN
# freq      1035       197          NaN            NaN            NaN
# mean       NaN       NaN  2010.498018   41875.531057   24410.926652
# std        NaN       NaN     2.773451   33146.564303   16300.355339
# min        NaN       NaN  1990.000000       1.000000    1490.000000
# 25%        NaN       NaN  2010.000000   20112.250000   15987.750000
# 50%        NaN       NaN  2011.000000   33532.000000   21500.000000
# 75%        NaN       NaN  2012.000000   52564.500000   28998.000000
# max        NaN       NaN  2015.000000  279950.000000  499898.000000
#
#        Body Style Ex Color In Color Engine Transmission        Doors
# count        9080     9080     9080   9080         9080  9080.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9080 entries, 0 to 9079
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Make          9080 non-null   object
#  1   Model         9080 non-null   object
#  2   Year          9080 non-null   int64
#  3   Mileage       9080 non-null   int64
#  4   Price         9080 non-null   int64
#  5   Body Style    9080 non-null   object
#  6   Ex Color      9080 non-null   object
#  7   In Color      9080 non-null   object
#  8   Engine        9080 non-null   object
#  9   Transmission  9080 non-null   object
#  10  Doors         9080 non-null   int64
# dtypes: int64(4), object(7)
# memory usage: 780.4+ KB

# %%
df = df.astype({'Make':'category', 'Model':'category', 'Year':'int32', 
                'Mileage':'int32', 'Price':'int64', 'Body Style':'category', 
                'Ex Color':'category' , 'In Color':'category', 
                'Engine':'category', 'Transmission':'category', 'Doors':'int32'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9080 entries, 0 to 9079
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Make          9080 non-null   category
#  1   Model         9080 non-null   category
#  2   Year          9080 non-null   int32
#  3   Mileage       9080 non-null   int32
#  4   Price         9080 non-null   int64
#  5   Body Style    9080 non-null   category
#  6   Ex Color      9080 non-null   category
#  7   In Color      9080 non-null   category
#  8   Engine        9080 non-null   category
#  9   Transmission  9080 non-null   category
#  10  Doors         9080 non-null   int32
# dtypes: category(7), int32(3), int64(1)
# memory usage: 292.3 KB

# %%
df.describe(include='all')
# Out:
#           Make     Model         Year        Mileage          Price  \
# count     9080      9080  9080.000000    9080.000000    9080.000000
# unique      49      1060          NaN            NaN            NaN
# top     Nissan  Altima S          NaN            NaN            NaN
# freq      1035       197          NaN            NaN            NaN
# mean       NaN       NaN  2010.498018   41875.531057   24410.926652
# std        NaN       NaN     2.773451   33146.564303   16300.355339
# min        NaN       NaN  1990.000000       1.000000    1490.000000
# 25%        NaN       NaN  2010.000000   20112.250000   15987.750000
# 50%        NaN       NaN  2011.000000   33532.000000   21500.000000
# 75%        NaN       NaN  2012.000000   52564.500000   28998.000000
# max        NaN       NaN  2015.000000  279950.000000  499898.000000
#
#        Body Style Ex Color In Color Engine Transmission        Doors
# count        9080     9080     9080   9080         9080  9080.000000
# ...

# %%
df['Price'].describe()
# Out:
# count      9080.000000
# mean      24410.926652
# std       16300.355339
# min        1490.000000
# 25%       15987.750000
# 50%       21500.000000
# 75%       28998.000000
# max      499898.000000
# Name: Price, dtype: float64

# %%
print('Correlation:')
df[["Price", "Mileage"]].corr(numeric_only=True)
# Out:
# Correlation:
#             Price   Mileage
# Price    1.000000 -0.405068
# Mileage -0.405068  1.000000

# %%
sns.pairplot(df[["Price", "Mileage"]])

# %% [markdown]
# ### Performing Data Preprocessing

# %%
# Fetching categorical columns
cat_cols = df.select_dtypes(include='category').columns.tolist()
print("Categorical columns requiring encoding:\n", cat_cols)

# print("\nUnique value counts:")
# for col in cat_cols:
#     print(f"  {col}: {X[col].nunique()} unique values")
# Out:
# Categorical columns requiring encoding:
#  ['Make', 'Model', 'Body Style', 'Ex Color', 'In Color', 'Engine', 'Transmission']

# %%
df_encoded = df.copy()

# %%
df_encoded
# Out:
#                Make                           Model  Year  Mileage  Price  \
# 0            Toyota                      Avalon XLE  2014     4725  28995
# 1              Ford                       Escape SE  2014    17201  24994
# 2           Hyundai                  Santa Fe Sport  2014     6279  25998
# 3              Ford                       Escape SE  2014    16262  26684
# 4              Jeep  Grand Cherokee Limited Edition  2014    35572  33440
# ...             ...                             ...   ...      ...    ...
# 9075      Chevrolet                       Malibu LT  2010    40340  12998
# 9076           Ford                        Edge SEL  2009    43169  18495
# 9077          Dodge                     Avenger SXT  2012     6761  14944
# 9078  Mercedes-Benz                          ML 350  2011    38215  35900
# 9079         Nissan                       Altima SL  2010    44065  13499
#
#      Body Style Ex Color In Color Engine Transmission  Doors
# ...

# %%
# # ── Label Encoding, ONLY for very high cardinality variables
# le = LabelEncoder()
# df_encoded['Model'] = le.fit_transform(df_encoded['Model'].astype(str))

# %%
# # ── One-Hot Encoding, all other categorical columns
# ohe_cols = ['Make', 'Body Style', 'Ex Color', 'In Color', 
#             'Engine', 'Transmission']
# df_encoded = pd.get_dummies(df_encoded, columns=ohe_cols, drop_first=True, dtype=int)

# %%
# Label Encoding → Model only (1060 unique — OHE would create 1059 columns)
le = LabelEncoder()
enc_cols = ['Make', "Model", 'Body Style', 'Ex Color', 'In Color', 
            'Engine', 'Transmission']

for col in enc_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))

# %%
print(f"Shape after encoding: {df_encoded.shape}")
# Out:
# Shape after encoding: (9080, 11)

# %%
df_encoded.head()
# Out:
#    Make  Model  Year  Mileage  Price  Body Style  Ex Color  In Color  Engine  \
# 0    46    134  2014     4725  28995           7         6         0       5
# 1    12    353  2014    17201  24994           6        12         0       3
# 2    16    840  2014     6279  25998           6        12         3       3
# 3    12    353  2014    16262  26684           6         1         0       3
# 4    19    485  2014    35572  33440           6         1         0       5
#
#    Transmission  Doors
# 0             0      4
# 1             0      4
# 2             0      4
# 3             0      4
# 4             0      4

# %%
X = df_encoded.drop(columns=['Price'])
y = df_encoded['Price']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.30,
    random_state=42
)

print(f"Training set : {X_train.shape}")
print(f"Testing set  : {X_test.shape}")
# Out:
# Training set : (6356, 10)
# Testing set  : (2724, 10)

# %%
#Normaliing numeric fields other than OHE  

numeric_cols = ['Make', 'Model', 'Year', 'Mileage', 'Body Style', 'Ex Color', 'In Color', 'Engine', 'Transmission', 'Doors']
scaler_X = StandardScaler()

X_train[numeric_cols] = scaler_X.fit_transform(X_train[numeric_cols])
X_test[numeric_cols]  = scaler_X.transform(X_test[numeric_cols])

# %%
scaler_y = StandardScaler()

y_train = scaler_y.fit_transform(y_train.values.reshape(-1,1)).flatten()
y_test  = scaler_y.transform(y_test.values.reshape(-1,1)).flatten()

# %%
y_train
# Out:
# array([ 0.50571504, -0.14521983, -0.44445966, ...,  0.72217496,
#        -0.08540775,  0.270833  ], shape=(6356,))

# %%
X_train
# Out:
#           Make     Model      Year   Mileage  Body Style  Ex Color  In Color  \
# 7531  1.712899  0.031303  0.544564 -0.600535   -0.020310 -0.182981  0.373153
# 5594 -1.296409 -1.476040 -0.182665  1.640748    0.609409 -1.191156 -0.937213
# 1979  1.712899  1.195618 -2.000739  1.341200   -0.020310 -0.989521 -0.937213
# 1883  0.103269  0.911960 -1.273510  1.274553   -0.020310  1.026828  2.120308
# 438   0.103269  0.908662  0.180949 -0.314792   -0.020310 -1.191156  0.373153
# ...        ...       ...       ...       ...         ...       ...       ...
# 5734 -0.666554 -0.189686  0.544564 -0.377547    0.609409  1.026828 -0.937213
# 5191  0.733124  1.172529  0.180949 -0.544256    0.609409  1.228463  0.373153
# 5390 -1.296409 -1.476040  0.180949 -0.494727    0.609409  0.018653  1.683520
# 860  -1.016473  1.245093  0.180949  1.143114   -0.650030 -0.989521 -0.937213
# 7270 -1.506361  1.347341  0.180949 -0.464292    0.609409 -0.182981 -0.937213
#
#         Engine  Transmission     Doors
# ...

# %% [markdown]
# ### Task 2: Implementing Linear Regression

# %%
X_train = X_train[['Make', 'Year', 'Mileage']]
X_test  = X_test[['Make', 'Year', 'Mileage']]

# %%
X_train
# Out:
#           Make      Year   Mileage
# 7531  1.712899  0.544564 -0.600535
# 5594 -1.296409 -0.182665  1.640748
# 1979  1.712899 -2.000739  1.341200
# 1883  0.103269 -1.273510  1.274553
# 438   0.103269  0.180949 -0.314792
# ...        ...       ...       ...
# 5734 -0.666554  0.544564 -0.377547
# 5191  0.733124  0.180949 -0.544256
# 5390 -1.296409  0.180949 -0.494727
# 860  -1.016473  0.180949  1.143114
# 7270 -1.506361  0.180949 -0.464292
#
# [6356 rows x 3 columns]

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.20386085070000826

# %%
lr.score(X_train, y_train)
# Out:
# 0.1750312563700841

# %%
# Predict
y_pred_train_lr = lr.predict(X_train)
y_pred_test_lr  = lr.predict(X_test)

# %%
# MSE on scaled values
mse_train_lr = mean_squared_error(y_train, y_pred_train_lr)
mse_test_lr  = mean_squared_error(y_test,  y_pred_test_lr)

# %%
print(f"MSE for train dataset: {mse_train_lr}")
print(f"MSE for test dataset: {mse_test_lr}")
# Out:
# MSE for train dataset: 0.8249687436299157
# MSE for test dataset: 0.6646085918988553

# %% [markdown]
# #### Tuning parameters with validation and ragularisation to improve model performance

# %%
# K-FOLD CROSS VALIDATION to find best Ridge LAMBDA

LAMBDAS = [0.001, 0.01, 0.1, 1, 10, 50, 100, 500, 1000]

kf = KFold(n_splits=5, shuffle=True, random_state=42)

cv_scores = []

for LAMBDA in LAMBDAS:
    ridge_lr = Ridge(alpha=LAMBDA)
    scores = cross_val_score(ridge_lr, X_train, y_train, cv=kf, scoring='neg_mean_squared_error')
    
    cv_scores.append(-scores.mean())   # convert back to positive MSE
    
    print(f"LAMBDA={LAMBDA:8.3f}  |  CV MSE={-scores.mean():.4f}")

best_lambda = LAMBDAS[np.argmin(cv_scores)]
print(f"\n✅ Best LAMBDA: {best_lambda}")
# Out:
# LAMBDA=   0.001  |  CV MSE=0.8261
# LAMBDA=   0.010  |  CV MSE=0.8261
# LAMBDA=   0.100  |  CV MSE=0.8261
# LAMBDA=   1.000  |  CV MSE=0.8261
# LAMBDA=  10.000  |  CV MSE=0.8261
# LAMBDA=  50.000  |  CV MSE=0.8261
# LAMBDA= 100.000  |  CV MSE=0.8261
# LAMBDA= 500.000  |  CV MSE=0.8268
# LAMBDA=1000.000  |  CV MSE=0.8286
#
# ✅ Best LAMBDA: 50

# %%
plt.figure(figsize=(9, 4))
plt.plot(LAMBDAS, cv_scores, marker='o', color='steelblue', linewidth=2)
plt.axvline(x=best_lambda, color='red', linestyle='--', 
            label=f'Best LAMBDA = {best_lambda}')
plt.xscale('log')
plt.xlabel('LAMBDA (Regularisation Strength)')
plt.ylabel('Cross-Validation MSE')
plt.title('Ridge Regression — K-Fold CV MSE vs LAMBDA')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()

# %%
# Training final optimal model after regularisation and validation, with best lambda

ridge_best_lr = Ridge(alpha=best_lambda)
ridge_best_lr.fit(X_train, y_train)
# Out:
# Ridge(alpha=50)

# %%
# Predict

y_pred_train_ridge_lr = ridge_best_lr.predict(X_train)
y_pred_test_ridge_lr  = ridge_best_lr.predict(X_test)

# %%
# MSE on scaled values

mse_train_ridge_lr = mean_squared_error(y_train, y_pred_train_ridge_lr)
mse_test_ridge_lr  = mean_squared_error(y_test,  y_pred_test_ridge_lr)


print(f"Best lambda : {best_lambda}")
print(f"Train MSE  : {mse_train_ridge_lr:.4f}")
print(f"Test  MSE  : {mse_test_ridge_lr:.4f}")
# Out:
# Best lambda : 50
# Train MSE  : 0.8250
# Test  MSE  : 0.6645

# %%
# Building and fitting RF model

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Predict

y_pred_train_rf = rf.predict(X_train)
y_pred_test_rf  = rf.predict(X_test)

# %%
mse_train_rf = mean_squared_error(y_train, y_pred_train_rf)
mse_test_rf  = mean_squared_error(y_test,  y_pred_test_rf)

print(f"Train MSE : {mse_train_rf:.4f}")
print(f"Test  MSE : {mse_test_rf:.4f}")
# Out:
# Train MSE : 0.0711
# Test  MSE : 0.3599

# %%
rf.score(X_train, y_train)
# Out:
# 0.9288722782934006

# %%
rf.score(X_test, y_test)
# Out:
# 0.5688268295809514
